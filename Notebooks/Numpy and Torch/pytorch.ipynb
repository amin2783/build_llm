# %%
# Import torch and check if GPU is available

import torch
torch.__version__
# Out:
# '2.8.0+cu126'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Torch uses NumPy like API for tensors.

# %%
tensor0d = torch.tensor(1)
display(tensor0d)

tensor1d = torch.tensor([1, 2, 3])
display(tensor1d)

tensor2d = torch.tensor([[1, 2], [3, 4]])
display(tensor2d)

tensor3d = torch.tensor([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
display(tensor3d)
# Out:
# tensor(1)
# tensor([1, 2, 3])
# tensor([[1, 2],
#         [3, 4]])
# tensor([[[1, 2],
#          [3, 4]],
#
#         [[5, 6],
#          [7, 8]]])

# %%
print(tensor1d.dtype)
# Out:
# torch.int64

# %%
floatvec = torch.tensor([1.0, 2.0, 3.0])
print(floatvec.dtype)
# Out:
# torch.float32

# %%
# Change dtype of an existing tensor
floatvec = tensor1d.to(torch.float32)
print(floatvec.dtype)
# Out:
# torch.float32

# %%
tensor2d = torch.tensor([[1, 2, 3],
                         [4, 5, 6]])

display(tensor2d)

tensor2d.shape
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])
# torch.Size([2, 3])
